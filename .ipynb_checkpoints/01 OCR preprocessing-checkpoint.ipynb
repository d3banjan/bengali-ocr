# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
# %matplotlib inline
mpl.rcParams['savefig.dpi'] = 300
mpl.rcParams['figure.dpi'] = 300
#test if inline works for notebook
x=np.linspace(start=-np.pi,stop=np.pi,num=20,endpoint=True)
y=np.sin(x)
plt.plot(x,y)

# %%
# second arg - {=0: B/W ; >0: 3-color channels ; <0: any-channel-size }
img=cv2.imread("W4Pio.jpg",0)
# image expressed as a 2D array of integers in 0-255
vmin,vmax=(0,255)
plt.imshow(img,cmap=plt.get_cmap("gray"),vmin=vmin,vmax=vmax)

# %%
import operator as op
def image_subplots(imagelist,fig, size=None):
    if size:
        assert len(imagelist)==reduce(op.mul,size)
    else:
        size=(len(imagelist),1)
    for index,img in zip(range(len(imagelist)),imagelist):
        fig.add_subplot(size[0],size[1],index+1)
        plt.imshow(img,cmap=plt.get_cmap("gray"))

# %%
imglist=[cv2.blur(img,(i,i)) for i in [1,2,4,6,8,10]]
fig=plt.figure()
image_subplots(imglist,fig,size=(3,2))
plt.show()

# %%
img.shape
# Out:
# (991, 701)

# %%
fig=plt.figure()
imgcroplist=[img[400:500,300:400] for img in imglist]
image_subplots(imgcroplist,fig,size=(3,2))
plt.show()

# %%
# ?cv2.threshold()

# %%
threshlist=[cv2.THRESH_BINARY,cv2.THRESH_BINARY_INV,cv2.THRESH_MASK,cv2.THRESH_OTSU,cv2.THRESH_TOZERO,
            cv2.THRESH_TOZERO_INV,cv2.THRESH_TRIANGLE,cv2.THRESH_TRUNC]
imgthreshlist=[cv2.threshold(imgcroplist[0],thresh=100,maxval=255,type=thresh) for thresh in threshlist]
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-13-3f0ba6e21dde> in <module>()
#       1 threshlist=[cv2.THRESH_BINARY,cv2.THRESH_BINARY_INV,cv2.THRESH_MASK,cv2.THRESH_OTSU,cv2.THRESH_TOZERO,
#       2             cv2.THRESH_TOZERO_INV,cv2.THRESH_TRIANGLE,cv2.THRESH_TRUNC]
# ----> 3 imgthreshlist=[cv2.threshold(imgcroplist[0],thresh=100,maxval=255,type=thresh) for thresh in threshlist]
#
# error: /io/opencv/modules/imgproc/src/thresh.cpp:161: error: (-5) Unknown threshold type in function thresh_8u
